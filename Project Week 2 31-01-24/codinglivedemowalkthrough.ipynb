# %% [markdown]
# <a href="https://colab.research.google.com/github/mushy2003/CSinSchools/blob/main/codinglivedemowalkthrough.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
import pandas as pd

# %%
train = pd.read_csv("sample_data/california_housing_train.csv")
test = pd.read_csv("sample_data/california_housing_test.csv")

train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
# ...

# %%
linear_model = LinearRegression()
linear_model
# Out:
# LinearRegression()

# %%
X_train = train.iloc[:, :-1]
X_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -114.31     34.19                15.0       5612.0          1283.0
# 1        -114.47     34.40                19.0       7650.0          1901.0
# 2        -114.56     33.69                17.0        720.0           174.0
# 3        -114.57     33.64                14.0       1501.0           337.0
# 4        -114.57     33.57                20.0       1454.0           326.0
# ...          ...       ...                 ...          ...             ...
# 16995    -124.26     40.58                52.0       2217.0           394.0
# 16996    -124.27     40.69                36.0       2349.0           528.0
# 16997    -124.30     41.84                17.0       2677.0           531.0
# 16998    -124.30     41.80                19.0       2672.0           552.0
# 16999    -124.35     40.54                52.0       1820.0           300.0
#
#        population  households  median_income
# ...

# %%
lst = np.array([[1, 2, 3], [4, 5, 6]])
lst[0:2, [1, 2]]
# Out:
# array([[2, 3],
#        [5, 6]])

# %%
y_train = train.iloc[:, -1]
y_train
# Out:
# 0         66900.0
# 1         80100.0
# 2         85700.0
# 3         73400.0
# 4         65500.0
#            ...
# 16995    111400.0
# 16996     79000.0
# 16997    103600.0
# 16998     85800.0
# 16999     94600.0
# Name: median_house_value, Length: 17000, dtype: float64

# %%
linear_model.fit(X_train, y_train) #training
# Out:
# LinearRegression()

# %%
x_test = test.iloc[:, :-1]
y_test = test.iloc[:, -1]

# %%
predictions = linear_model.predict(x_test)
predictions
# Out:
# array([352812.31112454, 212717.70074518, 272344.69951888, ...,
#         88220.58643733, 146374.67481457, 456779.61107787])

# %%
import matplotlib.pyplot as plt
y_test = test.iloc[:, -1]
plt.scatter(predictions, y_test)
